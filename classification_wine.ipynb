# %% [markdown]
# <a href="https://colab.research.google.com/github/changcw2022/AI_ML/blob/main/classification_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.datasets import load_wine
wine = load_wine()
df = pd.DataFrame(wine['data'], columns=wine['feature_names'])
df['target']=wine['target']
df.to_csv('wine.csv', encoding='utf-8', index=False)

# %%
x = np.array(wine['data'])
y = np.array(wine['target'])

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
x = np.array(df.drop(['target'], axis=1))
y = np.array(df['target'])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30))
plot_tree(clf,
          feature_names=wine['feature_names'],
          class_names=wine['target_names'],
          filled=True
          )
# Out:
# [Text(0.5, 0.8333333333333334, 'proline <= 755.0\ngini = 0.658\nsamples = 160\nvalue = [53, 64, 43]\nclass = class_1'),
#  Text(0.25, 0.5, 'color_intensity <= 4.85\ngini = 0.495\nsamples = 100\nvalue = [2, 60, 38]\nclass = class_1'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.151\nsamples = 62\nvalue = [2, 57, 3]\nclass = class_1'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.145\nsamples = 38\nvalue = [0, 3, 35]\nclass = class_2'),
#  Text(0.75, 0.5, 'flavanoids <= 2.165\ngini = 0.266\nsamples = 60\nvalue = [51, 4, 5]\nclass = class_0'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.408\nsamples = 7\nvalue = [0, 2, 5]\nclass = class_2'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.073\nsamples = 53\nvalue = [51, 2, 0]\nclass = class_0')]

# %%
from sklearn.metrics import accuracy_score
pre = clf.predict(x_test)
accuracy_score(y_test, pre)
# Out:
# 0.8888888888888888

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True)
